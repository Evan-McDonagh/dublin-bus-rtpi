# %%
import numpy as np 
import pandas as pd

# %%
trips = pd.read_csv('google_transit_dublinbus/trips.txt',sep=',')
stop_times = pd.read_csv('google_transit_dublinbus/stop_times.txt',sep=',')
routes = pd.read_csv('google_transit_dublinbus/routes.txt',sep=',')

# %%
trips.head()
# Out:
#       route_id service_id                  trip_id          shape_id  \
# 0  60-11-b12-1          1  3271.1.60-11-b12-1.16.I  60-11-b12-1.16.I
# 1  60-11-b12-1          1  3272.1.60-11-b12-1.15.O  60-11-b12-1.15.O
# 2  60-11-b12-1          1  3273.1.60-11-b12-1.16.I  60-11-b12-1.16.I
# 3  60-11-b12-1          1  3274.1.60-11-b12-1.15.O  60-11-b12-1.15.O
# 4  60-11-b12-1          1  3275.1.60-11-b12-1.16.I  60-11-b12-1.16.I
#
#                                        trip_headsign  direction_id
# 0              Blackthorn Road - Saint Pappin's Road             1
# 1  Saint Pappin's Road - Blackthorn Drive (Blackt...             0
# 2              Blackthorn Road - Saint Pappin's Road             1
# 3  Saint Pappin's Road - Blackthorn Drive (Blackt...             0
# 4              Blackthorn Road - Saint Pappin's Road             1

# %%
stop_times.head()
# Out:
#                   trip_id arrival_time departure_time       stop_id  \
# 0  1.1.60-39A-b12-1.205.I     07:55:00       07:55:00  8240DB007158
# 1  1.1.60-39A-b12-1.205.I     07:55:43       07:55:43  8240DB007048
# 2  1.1.60-39A-b12-1.205.I     07:56:27       07:56:27  8240DB007699
# 3  1.1.60-39A-b12-1.205.I     07:56:54       07:56:54  8240DB007159
# 4  1.1.60-39A-b12-1.205.I     07:57:13       07:57:13  8240DB007388
#
#    stop_sequence stop_headsign  pickup_type  drop_off_type  \
# 0              1           UCD            0              0
# 1              2           UCD            0              0
# 2              3           UCD            0              0
# 3              4           UCD            0              0
# 4              5           UCD            0              0
#
#    shape_dist_traveled
# 0                 0.00
# 1            750698.41
# 2           1501239.38
# 3           2251660.48
# 4           3001993.17

# %%
routes.head()
# Out:
#        route_id  agency_id route_short_name  route_long_name  route_type
# 0    60-1-b12-1        978                1              NaN           3
# 1  60-102-b12-1        978              102              NaN           3
# 2  60-104-b12-1        978              104              NaN           3
# 3   60-11-b12-1        978               11              NaN           3
# 4  60-111-b12-1        978              111              NaN           3

# %%
df = stop_times.merge(trips,on='trip_id')

# %%
df.head()
# Out:
#                   trip_id arrival_time departure_time       stop_id  \
# 0  1.1.60-39A-b12-1.205.I     07:55:00       07:55:00  8240DB007158
# 1  1.1.60-39A-b12-1.205.I     07:55:43       07:55:43  8240DB007048
# 2  1.1.60-39A-b12-1.205.I     07:56:27       07:56:27  8240DB007699
# 3  1.1.60-39A-b12-1.205.I     07:56:54       07:56:54  8240DB007159
# 4  1.1.60-39A-b12-1.205.I     07:57:13       07:57:13  8240DB007388
#
#    stop_sequence stop_headsign  pickup_type  drop_off_type  \
# 0              1           UCD            0              0
# 1              2           UCD            0              0
# 2              3           UCD            0              0
# 3              4           UCD            0              0
# 4              5           UCD            0              0
#
#    shape_dist_traveled      route_id service_id            shape_id  \
# 0                 0.00  60-39A-b12-1          1  60-39A-b12-1.205.I
# 1            750698.41  60-39A-b12-1          1  60-39A-b12-1.205.I
# 2           1501239.38  60-39A-b12-1          1  60-39A-b12-1.205.I
# 3           2251660.48  60-39A-b12-1          1  60-39A-b12-1.205.I
# 4           3001993.17  60-39A-b12-1          1  60-39A-b12-1.205.I
#
#                                  trip_headsign  direction_id
# 0  Delhurst Estate - University College Dublin             1
# 1  Delhurst Estate - University College Dublin             1
# 2  Delhurst Estate - University College Dublin             1
# 3  Delhurst Estate - University College Dublin             1
# 4  Delhurst Estate - University College Dublin             1

# %%
df = df.merge(routes,on='route_id')

# %%
df.head()
# Out:
#                   trip_id arrival_time departure_time       stop_id  \
# 0  1.1.60-39A-b12-1.205.I     07:55:00       07:55:00  8240DB007158
# 1  1.1.60-39A-b12-1.205.I     07:55:43       07:55:43  8240DB007048
# 2  1.1.60-39A-b12-1.205.I     07:56:27       07:56:27  8240DB007699
# 3  1.1.60-39A-b12-1.205.I     07:56:54       07:56:54  8240DB007159
# 4  1.1.60-39A-b12-1.205.I     07:57:13       07:57:13  8240DB007388
#
#    stop_sequence stop_headsign  pickup_type  drop_off_type  \
# 0              1           UCD            0              0
# 1              2           UCD            0              0
# 2              3           UCD            0              0
# 3              4           UCD            0              0
# 4              5           UCD            0              0
#
#    shape_dist_traveled      route_id service_id            shape_id  \
# 0                 0.00  60-39A-b12-1          1  60-39A-b12-1.205.I
# 1            750698.41  60-39A-b12-1          1  60-39A-b12-1.205.I
# 2           1501239.38  60-39A-b12-1          1  60-39A-b12-1.205.I
# 3           2251660.48  60-39A-b12-1          1  60-39A-b12-1.205.I
# 4           3001993.17  60-39A-b12-1          1  60-39A-b12-1.205.I
#
#                                  trip_headsign  direction_id  agency_id  \
# 0  Delhurst Estate - University College Dublin             1        978
# 1  Delhurst Estate - University College Dublin             1        978
# 2  Delhurst Estate - University College Dublin             1        978
# 3  Delhurst Estate - University College Dublin             1        978
# 4  Delhurst Estate - University College Dublin             1        978
#
#   route_short_name  route_long_name  route_type
# 0              39a              NaN           3
# 1              39a              NaN           3
# 2              39a              NaN           3
# 3              39a              NaN           3
# 4              39a              NaN           3

# %%
df.dtypes
# Out:
# trip_id                 object
# arrival_time            object
# departure_time          object
# stop_id                 object
# stop_sequence            int64
# stop_headsign           object
# pickup_type              int64
# drop_off_type            int64
# shape_dist_traveled    float64
# route_id                object
# service_id              object
# shape_id                object
# trip_headsign           object
# direction_id             int64
# agency_id                int64
# route_short_name        object
# route_long_name        float64
# route_type               int64
# dtype: object

# %%
df.drop(['stop_headsign','pickup_type','drop_off_type','shape_dist_traveled','service_id','trip_headsign','agency_id','route_long_name','route_type'],inplace=True,axis=1)

# %%
df.head()
# Out:
#                   trip_id arrival_time departure_time       stop_id  \
# 0  1.1.60-39A-b12-1.205.I     07:55:00       07:55:00  8240DB007158
# 1  1.1.60-39A-b12-1.205.I     07:55:43       07:55:43  8240DB007048
# 2  1.1.60-39A-b12-1.205.I     07:56:27       07:56:27  8240DB007699
# 3  1.1.60-39A-b12-1.205.I     07:56:54       07:56:54  8240DB007159
# 4  1.1.60-39A-b12-1.205.I     07:57:13       07:57:13  8240DB007388
#
#    stop_sequence      route_id            shape_id  direction_id  \
# 0              1  60-39A-b12-1  60-39A-b12-1.205.I             1
# 1              2  60-39A-b12-1  60-39A-b12-1.205.I             1
# 2              3  60-39A-b12-1  60-39A-b12-1.205.I             1
# 3              4  60-39A-b12-1  60-39A-b12-1.205.I             1
# 4              5  60-39A-b12-1  60-39A-b12-1.205.I             1
#
#   route_short_name
# 0              39a
# 1              39a
# 2              39a
# 3              39a
# 4              39a

# %%
df.shape
# Out:
# (1573337, 9)

# %%
df[df['trip_id'] == '10964.y1001.60-155-d12-1.94.I'][df['stop_sequence']==df['stop_sequence'].min()]
# Out:
# C:\Users\Mesel\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#                               trip_id arrival_time departure_time  \
# 464087  10964.y1001.60-155-d12-1.94.I     06:00:00       06:00:00
#
#              stop_id  stop_sequence      route_id           shape_id  \
# 464087  8350DB004168              1  60-155-d12-1  60-155-d12-1.94.I
#
#         direction_id route_short_name
# 464087             1              155

# %%
df[df['trip_id'] == '10964.y1001.60-155-d12-1.94.I'][df['stop_sequence']==df['stop_sequence'].max()]
# Out:
# C:\Users\Mesel\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# Empty DataFrame
# Columns: [trip_id, arrival_time, departure_time, stop_id, stop_sequence, route_id, shape_id, direction_id, route_short_name]
# Index: []

# %%
df[df['trip_id'] == '10964.y1001.60-155-d12-1.94.I']['stop_sequence'].min()
# Out:
# 1

# %%
df_trip = df[df['trip_id'] == '10964.y1001.60-155-d12-1.94.I']
df_trip_max = df_trip[df_trip['stop_sequence'] == df_trip['stop_sequence'].max()]['arrival_time'].iloc[0]
df_trip_min = df_trip[df_trip['stop_sequence'] == df_trip['stop_sequence'].min()]['arrival_time'].iloc[0]
df_trip_max
# Out:
# '06:53:45'

# %%
trip_mins = []
i = 0
for trip in df['trip_id'].unique():
    df_trip = df[df['trip_id'] == trip]
    df_trip_max = df_trip[df_trip['stop_sequence'] == df_trip['stop_sequence'].max()]['arrival_time'].iloc[0]
    df_trip_min = df_trip[df_trip['stop_sequence'] == df_trip['stop_sequence'].min()]['arrival_time'].iloc[0]
    i += 1
    if i % 1000 == 0:
        print(i)
# Out:
# 1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-334584bea6a1> in <module>
#       2 i = 0
#       3 for trip in df['trip_id'].unique():
# ----> 4     df_trip = df[df['trip_id'] == trip]
#       5     df_trip_max = df_trip[df_trip['stop_sequence'] == df_trip['stop_sequence'].max()]['arrival_time'].iloc[0]
#       6     df_trip_min = df_trip[df_trip['stop_sequence'] == df_trip['stop_sequence'].min()]['arrival_time'].iloc[0]
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#     527         rvalues = extract_array(other, extract_numpy=True)
#     528
# --> 529         res_values = comparison_op(lvalues, rvalues, op)
#     530
#     531         return _construct_result(self, res_values, index=self.index, name=res_name)
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     245
#     246     elif is_object_dtype(lvalues.dtype):
# --> 247         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     248
#     249     else:
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      56     else:
#      57         result = libops.scalar_compare(x.ravel(), y, op)
# ---> 58     return result.reshape(x.shape)
#      59
#      60
#
# KeyboardInterrupt:

# %%
len(df[df['route_short_name'] == '1']['trip_id'].unique())
# Out:
# 538

# %%
df.head()
# Out:
#                   trip_id arrival_time departure_time       stop_id  \
# 0  1.1.60-39A-b12-1.205.I     07:55:00       07:55:00  8240DB007158
# 1  1.1.60-39A-b12-1.205.I     07:55:43       07:55:43  8240DB007048
# 2  1.1.60-39A-b12-1.205.I     07:56:27       07:56:27  8240DB007699
# 3  1.1.60-39A-b12-1.205.I     07:56:54       07:56:54  8240DB007159
# 4  1.1.60-39A-b12-1.205.I     07:57:13       07:57:13  8240DB007388
#
#    stop_sequence      route_id            shape_id  direction_id  \
# 0              1  60-39A-b12-1  60-39A-b12-1.205.I             1
# 1              2  60-39A-b12-1  60-39A-b12-1.205.I             1
# 2              3  60-39A-b12-1  60-39A-b12-1.205.I             1
# 3              4  60-39A-b12-1  60-39A-b12-1.205.I             1
# 4              5  60-39A-b12-1  60-39A-b12-1.205.I             1
#
#   route_short_name
# 0              39a
# 1              39a
# 2              39a
# 3              39a
# 4              39a

# %%
grouped_df = df.groupby('trip_id')

# %%
trip_start_time = grouped_df['arrival_time'].min()

# %%
trip_end_time = grouped_df['arrival_time'].max()

# %%
trip_end_time
# Out:
# trip_id
# 1.1.60-39A-b12-1.205.I           09:04:31
# 1.y1002.60-39A-d12-1.204.I       09:05:41
# 10.1.60-151-b12-1.90.I           09:35:14
# 10.y1002.60-151-d12-1.89.I       09:34:37
# 100.1.60-151-b12-1.89.O          21:14:33
#                                    ...
# 9997.y1001.60-25A-d12-1.139.I    11:49:54
# 9998.3.60-39A-b12-1.205.I        20:51:16
# 9998.y1001.60-25A-d12-1.140.O    13:03:58
# 9999.3.60-39A-b12-1.202.O        22:12:35
# 9999.y1001.60-25A-d12-1.139.I    14:14:31
# Name: arrival_time, Length: 27529, dtype: object

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, str_rep)
#     148     try:
# --> 149         result = expressions.evaluate(op, str_rep, left, right)
#     150     except TypeError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in evaluate(op, op_str, a, b, use_numexpr)
#     207     if use_numexpr:
# --> 208         return _evaluate(op, op_str, a, b)
#     209     return _evaluate_standard(op, op_str, a, b)
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_numexpr(op, op_str, a, b)
#     120     if result is None:
# --> 121         result = _evaluate_standard(op, op_str, a, b)
#     122
#
# ~\Anaconda3\lib\site-packages\pandas\core\computation\expressions.py in _evaluate_standard(op, op_str, a, b)
#      69     with np.errstate(all="ignore"):
# ---> 70         return op(a, b)
#      71
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-e0aff810f286> in <module>
# ----> 1 trip_length = trip_end_time - trip_start_time
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(left, right)
#     501         lvalues = extract_array(left, extract_numpy=True)
#     502         rvalues = extract_array(right, extract_numpy=True)
# --> 503         result = arithmetic_op(lvalues, rvalues, op, str_rep)
#     504
#     505         return _construct_result(left, result, index=left.index, name=res_name)
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in arithmetic_op(left, right, op, str_rep)
#     195     else:
#     196         with np.errstate(all="ignore"):
# --> 197             res_values = na_arithmetic_op(lvalues, rvalues, op, str_rep)
#     198
#     199     return res_values
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_arithmetic_op(left, right, op, str_rep)
#     149         result = expressions.evaluate(op, str_rep, left, right)
#     150     except TypeError:
# --> 151         result = masked_arith_op(left, right, op)
#     152
#     153     return missing.dispatch_fill_zeros(op, left, right, result)
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in masked_arith_op(x, y, op)
#      92         if mask.any():
#      93             with np.errstate(all="ignore"):
# ---> 94                 result[mask] = op(xrav[mask], yrav[mask])
#      95
#      96     else:
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
