# %%
import pandas as pd
import numpy as np
import pickle

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_score
from sklearn.tree import export_graphviz
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
import datetime

# %%
filename = "models_SVR/models.pkl"
stopfractionsname = "stopfractions.pkl"
models = pickle.load(open(filename, "rb"))

# %%
def get_prediction(route,direction,datestring,stopA,stopB):
    datetime_departure = datetime.datetime.strptime(datestring,'%Y-%m-%d %H:%M:%S')
            
    forecast = find_forecast(datetime_departure)        
    
    prediction = predict_travel_time(route,direction,datetime_departure,forecast['feels_like'],forecast['weather_main'],stopA,stopB)
    
    return int(prediction)

def find_forecast(datetime_departure):
    forecast = get_5day_forcast()
    for i,f in enumerate(forecast['list']):
        if datetime.datetime.fromtimestamp(f['dt']) > datetime_departure:
            f_out = {'feels_like':f['main']['feels_like']-273.15,'weather_main':f['weather'][0]['main']}
            return f_out
    avg_monthly_weather = pickle.load(open('avg_monthly_weather.pkl','rb'))
    f_out = {
        'feels_like':avg_monthly_weather['feels_like'].iloc[datetime_departure.month],
        'weather_main':avg_monthly_weather['weather_main'].iloc[datetime_departure.month]
    }
    return f_out
    
def predict_travel_time(route,direction,datetime_departure,feels_like,weather_main,stopA,stopB):
    departure_times = pickle.load(open('departure_times.pkl','rb'))
    
    stopfractionsname = "stopfractions.pkl"
    stopfractions = pickle.load(open(stopfractionsname,'rb'))

    total_triptime = predict_total_triptime(route,direction,datetime_departure,feels_like,weather_main)
    
    stopA_frac = stopfractions[stopfractions['LINEID']==route][stopfractions['DIRECTION']==direction][stopfractions['STOPPOINTID']==stopA]['TRIP_FRAC'].iloc[0]
    stopB_frac = stopfractions[stopfractions['LINEID']==route][stopfractions['DIRECTION']==direction][stopfractions['STOPPOINTID']==stopB]['TRIP_FRAC'].iloc[0]
    fraction = stopB_frac - stopA_frac
    
    schedule = [datetime_departure.replace(hour=0, minute=0, second=0, microsecond=0) + datetime.timedelta(seconds=int(t)) for t in departure_times[route][direction][datetime_departure.weekday()]]

    predictions = predict_total_triptimes(route,direction,schedule,feels_like,weather_main)
    for i, start_time in enumerate(schedule):
        if start_time + datetime.timedelta(seconds=predictions[i]*stopA_frac) > datetime_departure:
            prediction = predictions[i]*fraction
            return prediction
            
def predict_fractional_triptime(route,direction,datetime_departure,feels_like,weather_main,stopA,stopB):
    stopfractionsname = "stopfractions.pkl"
    stopfractions = pickle.load(open(stopfractionsname,'rb'))

    total_triptime = predict_total_triptime(route,direction,datetime_departure,feels_like,weather_main)
    
    stopA_frac = stopfractions[stopfractions['LINEID']==route][stopfractions['DIRECTION']==direction][stopfractions['STOPPOINTID']==stopA]['TRIP_FRAC'].iloc[0]
    stopB_frac = stopfractions[stopfractions['LINEID']==route][stopfractions['DIRECTION']==direction][stopfractions['STOPPOINTID']==stopB]['TRIP_FRAC'].iloc[0]
    
    fraction = stopB_frac - stopA_frac
    return total_triptime*fraction
    
def predict_total_triptime(route,direction,datetime_departure,feels_like,weather_main):
    model = find_model(route,direction)
    
    feels_like = normalize(feels_like,model['max_feels_like'],model['min_feels_like'])
    
    time_in_seconds = datetime_departure.hour*60*60 + datetime_departure.minute*60 + datetime_departure.second
    plannedtime_dep_cos = np.cos(2*np.pi*time_in_seconds/(60*60*24))
    plannedtime_dep_sin = np.sin(2*np.pi*time_in_seconds/(60*60*24))
    month = datetime_departure.month
    weekday = datetime_departure.weekday()
    weekend = True if weekday in [5,6] else False
    rush_hour = (25200 < time_in_seconds < 32400) or (57600 < time_in_seconds < 68400)
    
    params = {
        'RUSH_HOUR_' + str(rush_hour):1,
        'PLANNEDTIME_DEP_COS':plannedtime_dep_cos,
        'PLANNEDTIME_DEP_SIN':plannedtime_dep_sin,
        'feels_like':feels_like,
        'MONTH_' + str(month):1,
        'WEEKDAY_' + str(weekday):1,
        'WEEKEND_' + str(weekend):1,
        'weather_main_' + str(weather_main):1
    }

    all_params = [feature for feature in model['columns']]
    for feature in all_params:
        if feature not in params:
            params[feature] = 0
    
    d = pd.DataFrame(params,index=[0],columns=model['columns'])
    
#     prediction = unnormalize(model['model'].predict(d), model['max_trip'], model['min_trip'])
    prediction = model['model'].predict(d)
    return prediction

def predict_total_triptimes(route,direction,datetimes_departure,feels_like,weather_main):
    model = find_model(route,direction)
    
    feels_like = normalize(feels_like,model['max_feels_like'],model['min_feels_like'])
    
    params = {feature:[0]*len(datetimes_departure) for feature in model['columns']}
    
    for i, dt in enumerate(datetimes_departure):
        time_in_seconds = dt.hour*60*60 + dt.minute*60 + dt.second
        plannedtime_dep_cos = np.cos(2*np.pi*time_in_seconds/(60*60*24))
        plannedtime_dep_sin = np.sin(2*np.pi*time_in_seconds/(60*60*24))
        month = dt.month
        weekday = dt.weekday()
        weekend = True if weekday in [5,6] else False
        rush_hour = (25200 < time_in_seconds < 32400) or (57600 < time_in_seconds < 68400)
    
        params['RUSH_HOUR_' + str(rush_hour)][i] = 1
        params['PLANNEDTIME_DEP_COS'][i] = plannedtime_dep_cos
        params['PLANNEDTIME_DEP_SIN'][i] = plannedtime_dep_sin
        params['feels_like'][i] = 1
        params['MONTH_' + str(month)][i] = 1
        params['WEEKDAY_' + str(weekday)][i] = 1
        params['WEEKEND_' + str(weekend)][i] = 1
        params['weather_main_' + str(weather_main)][i] = 1
    
    d = pd.DataFrame(params,index=[i for i in range(len(datetimes_departure))],columns=model['columns'])
    
    predictions = unnormalize(model['model'].predict(d), model['max_trip'], model['min_trip'])
    
    return predictions

def unnormalize(x_norm,x_max,x_min):
    return x_norm*(x_max - x_min) + x_min

def normalize(x,x_max,x_min):
    return (x - x_min)/(x_max - x_min)

def find_model(route,direction):
    filename = "models_SVR/models.pkl"
    models = pickle.load(open(filename, "rb"))
    for model in models:
        if model['route'] == route and model['direction'] == direction:
            return model
        
def get_5day_forcast():
    import requests

    """Scrapes weather data from openweathermap.org"""
    
    API_KEY = "16fb93e92d3bd8aefd9b647c1a8f6acf"
    URL = "http://api.openweathermap.org/data/2.5/forecast?q=Dublin,ie&appid=" + API_KEY
    
#     time = get_datetime()
    try:
        r = requests.get(url = URL)
    except: 
        print("Scraping error: data not collected.")
        return None
    
    weather = r.json()
    return weather

# %%
d = predict_total_triptime('46A',1,today,0,'Drizzle')

# %%
d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-e983f374794d> in <module>
# ----> 1 d
#
# NameError: name 'd' is not defined

# %%
import datetime

today = datetime.datetime.now()

# %%
weekday = today.weekday()

# %%
weekday
# Out:
# 3

# %%
weekend = True if weekday in [5,6] else False

# %%
weekend
# Out:
# False

# %%
str(True)
# Out:
# 'True'

# %%
# predict_fractional_triptime('1',1,today,0,'Drizzle',48,44)

predict_travel_time('1',1,today,20,'Drizzle',48,44)
# Out:
# C:\Users\Mesel\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\Mesel\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# 325.8525642888964

# %%
dftrips = pd.read_csv('../../data/rt_trips_DB_2018.txt',sep=';')

dftrips.head()
# Out:
#   DATASOURCE        DAYOFSERVICE   TRIPID LINEID  ROUTEID  DIRECTION  \
# 0         DB  07-FEB-18 00:00:00  6253783     68    68_80          1
# 1         DB  07-FEB-18 00:00:00  6262138    25B  25B_271          2
# 2         DB  07-FEB-18 00:00:00  6254942    45A   45A_70          2
# 3         DB  07-FEB-18 00:00:00  6259460    25A  25A_273          1
# 4         DB  07-FEB-18 00:00:00  6253175     14    14_15          1
#
#    PLANNEDTIME_ARR  PLANNEDTIME_DEP  ACTUALTIME_ARR  ACTUALTIME_DEP   BASIN  \
# 0            87245            84600         87524.0         84600.0  BasDef
# 1            30517            26460         32752.0             NaN  BasDef
# 2            35512            32100         36329.0         32082.0  BasDef
# 3            57261            54420         58463.0         54443.0  BasDef
# 4            85383            81600         84682.0         81608.0  BasDef
#
#    TENDERLOT  SUPPRESSED  JUSTIFICATIONID          LASTUPDATE       NOTE
# 0        NaN         NaN              NaN  28-FEB-18 12:05:11  ,2967409,
# 1        NaN         NaN              NaN  28-FEB-18 12:05:11  ,2580260,
# 2        NaN         NaN              NaN  28-FEB-18 12:05:11  ,2448968,
# 3        NaN         NaN              NaN  28-FEB-18 12:05:11  ,3094242,
# 4        NaN         NaN              NaN  28-FEB-18 12:05:11  ,2526331,

# %%
dftrips.drop(['BASIN','TENDERLOT','SUPPRESSED','JUSTIFICATIONID','LASTUPDATE','NOTE','ACTUALTIME_ARR','ACTUALTIME_DEP','ROUTEID','TRIPID','DATASOURCE'],axis=1,inplace=True)

# %%
dftrips['DAYOFSERVICE'] = dftrips['DAYOFSERVICE'].astype('datetime64')
dftrips['LINEID'] = dftrips['LINEID'].astype('category')
dftrips['DIRECTION'] = dftrips['DIRECTION'].astype('category')

dftrips['WEEKDAY'] = dftrips['DAYOFSERVICE'].dt.weekday

# %%
dftrips.head()
# Out:
#   DAYOFSERVICE LINEID DIRECTION  PLANNEDTIME_ARR  PLANNEDTIME_DEP  WEEKDAY
# 0   2018-02-07     68         1            87245            84600        2
# 1   2018-02-07    25B         2            30517            26460        2
# 2   2018-02-07    45A         2            35512            32100        2
# 3   2018-02-07    25A         1            57261            54420        2
# 4   2018-02-07     14         1            85383            81600        2

# %%
departure_times = dict()
for route in dftrips['LINEID'].unique():
    departure_times[route] = dict()
    for direction in dftrips[dftrips['LINEID'] == route]['DIRECTION'].unique():
        departure_times[route][direction] = dict()
        for weekday in dftrips[dftrips['LINEID'] == route][dftrips['DIRECTION'] == direction]['WEEKDAY'].unique():
            departure_times[route][direction][weekday] = list()
            for plannedtime_dep in dftrips[dftrips['LINEID'] == route][dftrips['DIRECTION'] == direction][dftrips['WEEKDAY'] == weekday]['PLANNEDTIME_DEP'].unique():
                departure_times[route][direction][weekday] += [plannedtime_dep]
            departure_times[route][direction][weekday] = sorted(departure_times[route][direction][weekday])
# Out:
# C:\Users\Mesel\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\Mesel\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
pickle.dump(departure_times,open('departure_times.pkl','wb'))

# %%
print(departure_times['46A'][1][0])
# Out:
# [18900, 21960, 22080, 22500, 22560, 23040, 23520, 23580, 24000, 24120, 24480, 24660, 24960, 25200, 25440, 25740, 25920, 26100, 26280, 26400, 26820, 26880, 27000, 27360, 27600, 27840, 27900, 28320, 28440, 28800, 28980, 29280, 29400, 29520, 29760, 30000, 30060, 30240, 30600, 30720, 31140, 31200, 31680, 31800, 32100, 32160, 32220, 32400, 32640, 32760, 33000, 33120, 33300, 33600, 33840, 34080, 34200, 34380, 34560, 34800, 34920, 35040, 35100, 35400, 35460, 35520, 36000, 36480, 36540, 36600, 36900, 36960, 37080, 37200, 37440, 37620, 37800, 37920, 38160, 38400, 38700, 38880, 39000, 39240, 39360, 39600, 39780, 39840, 40200, 40320, 40500, 40800, 40860, 41280, 41400, 41760, 41940, 42000, 42240, 42300, 42480, 42600, 42720, 43020, 43200, 43560, 43680, 43800, 44100, 44160, 44400, 44640, 45000, 45120, 45180, 45600, 45720, 46080, 46200, 46260, 46560, 46800, 47040, 47340, 47400, 47520, 47880, 48000, 48420, 48480, 48600, 48960, 49200, 49440, 49500, 49800, 49920, 50040, 50400, 50580, 50880, 51000, 51120, 51360, 51600, 51660, 51840, 52200, 52320, 52740, 52800, 53280, 53400, 53760, 53820, 54000, 54240, 54360, 54600, 54720, 54900, 55200, 55440, 55680, 55800, 55980, 56160, 56400, 56520, 56640, 57000, 57060, 57120, 57600, 58080, 58140, 58200, 58560, 58680, 58800, 59040, 59220, 59400, 59520, 59760, 60000, 60300, 60480, 60600, 60780, 60840, 60960, 61200, 61380, 61440, 61800, 61920, 62280, 62400, 62460, 62880, 63000, 63360, 63540, 63600, 63840, 63900, 64080, 64200, 64320, 64620, 64800, 65160, 65280, 65400, 65700, 65760, 66000, 66240, 66600, 66720, 66780, 67200, 67320, 67680, 67800, 67860, 68160, 68400, 68580, 69000, 69300, 69600, 70200, 70800, 71100, 71400, 72000, 72600, 72900, 73200, 73800, 74400, 74700, 75000, 75600, 76500, 76800, 77400, 78000, 78300, 79200, 80100, 80400, 81000, 81600, 81900, 82800, 83700, 84600]

# %%
dt = datetime.datetime(2020,12,12,14,30)

# %%
forecast = get_5day_forcast()

# %%
forecast
# Out:
# {'cod': '200',
#  'message': 0,
#  'cnt': 40,
#  'list': [{'dt': 1595505600,
#    'main': {'temp': 290.35,
#     'feels_like': 288.9,
#     'temp_min': 290.35,
#     'temp_max': 291.06,
#     'pressure': 1012,
#     'sea_level': 1013,
#     'grnd_level': 1011,
#     'humidity': 86,
#     'temp_kf': -0.71},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 87},
#    'wind': {'speed': 4.3, 'deg': 266},
#    'visibility': 10000,
#    'pop': 0.79,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-23 12:00:00'},
#   {'dt': 1595516400,
#    'main': {'temp': 290.96,
#     'feels_like': 289.72,
#     'temp_min': 290.96,
#     'temp_max': 291.31,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1010,
#     'humidity': 81,
#     'temp_kf': -0.35},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 90},
#    'wind': {'speed': 3.83, 'deg': 281},
#    'visibility': 10000,
#    'pop': 0.24,
#    'rain': {'3h': 0.2},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-23 15:00:00'},
#   {'dt': 1595527200,
#    'main': {'temp': 290.85,
#     'feels_like': 289.45,
#     'temp_min': 290.85,
#     'temp_max': 290.93,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1010,
#     'humidity': 78,
#     'temp_kf': -0.08},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 89},
#    'wind': {'speed': 3.71, 'deg': 284},
#    'visibility': 10000,
#    'pop': 0.18,
#    'rain': {'3h': 0.17},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-23 18:00:00'},
#   {'dt': 1595538000,
#    'main': {'temp': 287.74,
#     'feels_like': 286.77,
#     'temp_min': 287.72,
#     'temp_max': 287.74,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1011,
#     'humidity': 90,
#     'temp_kf': 0.02},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 80},
#    'wind': {'speed': 2.71, 'deg': 261},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-07-23 21:00:00'},
#   {'dt': 1595548800,
#    'main': {'temp': 285.73,
#     'feels_like': 284.46,
#     'temp_min': 285.73,
#     'temp_max': 285.73,
#     'pressure': 1013,
#     'sea_level': 1013,
#     'grnd_level': 1011,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 43},
#    'wind': {'speed': 2.41, 'deg': 268},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-07-24 00:00:00'},
#   {'dt': 1595559600,
#    'main': {'temp': 284.52,
#     'feels_like': 282.69,
#     'temp_min': 284.52,
#     'temp_max': 284.52,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1010,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03n'}],
#    'clouds': {'all': 30},
#    'wind': {'speed': 2.73, 'deg': 261},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-07-24 03:00:00'},
#   {'dt': 1595570400,
#    'main': {'temp': 285.44,
#     'feels_like': 283.99,
#     'temp_min': 285.44,
#     'temp_max': 285.44,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1010,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 36},
#    'wind': {'speed': 2.41, 'deg': 254},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-24 06:00:00'},
#   {'dt': 1595581200,
#    'main': {'temp': 289.92,
#     'feels_like': 288.99,
#     'temp_min': 289.92,
#     'temp_max': 289.92,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1010,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 64},
#    'wind': {'speed': 2.26, 'deg': 243},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-24 09:00:00'},
#   {'dt': 1595592000,
#    'main': {'temp': 292.28,
#     'feels_like': 291.77,
#     'temp_min': 292.28,
#     'temp_max': 292.28,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1009,
#     'humidity': 66,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 82},
#    'wind': {'speed': 1.89, 'deg': 199},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-24 12:00:00'},
#   {'dt': 1595602800,
#    'main': {'temp': 292.97,
#     'feels_like': 292.25,
#     'temp_min': 292.97,
#     'temp_max': 292.97,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1007,
#     'humidity': 69,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.81, 'deg': 212},
#    'visibility': 10000,
#    'pop': 0.04,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-24 15:00:00'},
#   {'dt': 1595613600,
#    'main': {'temp': 290.03,
#     'feels_like': 289.99,
#     'temp_min': 290.03,
#     'temp_max': 290.03,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1005,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.58, 'deg': 204},
#    'visibility': 10000,
#    'pop': 0.95,
#    'rain': {'3h': 3.12},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-24 18:00:00'},
#   {'dt': 1595624400,
#    'main': {'temp': 289.26,
#     'feels_like': 287.83,
#     'temp_min': 289.26,
#     'temp_max': 289.26,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 1005,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.25, 'deg': 238},
#    'visibility': 10000,
#    'pop': 0.95,
#    'rain': {'3h': 1.23},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-07-24 21:00:00'},
#   {'dt': 1595635200,
#    'main': {'temp': 288.61,
#     'feels_like': 286.88,
#     'temp_min': 288.61,
#     'temp_max': 288.61,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 1003,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 4.27, 'deg': 233},
#    'visibility': 10000,
#    'pop': 0.85,
#    'rain': {'3h': 0.66},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-07-25 00:00:00'},
#   {'dt': 1595646000,
#    'main': {'temp': 288.36,
#     'feels_like': 287.52,
#     'temp_min': 288.36,
#     'temp_max': 288.36,
#     'pressure': 1004,
#     'sea_level': 1004,
#     'grnd_level': 1002,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 97},
#    'wind': {'speed': 2.89, 'deg': 220},
#    'visibility': 10000,
#    'pop': 0.47,
#    'rain': {'3h': 0.17},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-07-25 03:00:00'},
#   {'dt': 1595656800,
#    'main': {'temp': 288.83,
#     'feels_like': 287.05,
#     'temp_min': 288.83,
#     'temp_max': 288.83,
#     'pressure': 1004,
#     'sea_level': 1004,
#     'grnd_level': 1002,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 4.45, 'deg': 255},
#    'visibility': 10000,
#    'pop': 0.69,
#    'rain': {'3h': 0.18},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-25 06:00:00'},
#   {'dt': 1595667600,
#    'main': {'temp': 289.47,
#     'feels_like': 287.18,
#     'temp_min': 289.47,
#     'temp_max': 289.47,
#     'pressure': 1004,
#     'sea_level': 1004,
#     'grnd_level': 1002,
#     'humidity': 80,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.54, 'deg': 268},
#    'visibility': 10000,
#    'pop': 0.22,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-25 09:00:00'},
#   {'dt': 1595678400,
#    'main': {'temp': 292.31,
#     'feels_like': 290.44,
#     'temp_min': 292.31,
#     'temp_max': 292.31,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 1003,
#     'humidity': 68,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.05, 'deg': 273},
#    'visibility': 10000,
#    'pop': 0.32,
#    'rain': {'3h': 0.19},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-25 12:00:00'},
#   {'dt': 1595689200,
#    'main': {'temp': 292.15,
#     'feels_like': 290.34,
#     'temp_min': 292.15,
#     'temp_max': 292.15,
#     'pressure': 1004,
#     'sea_level': 1004,
#     'grnd_level': 1002,
#     'humidity': 70,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.1, 'deg': 276},
#    'visibility': 10000,
#    'pop': 0.94,
#    'rain': {'3h': 0.97},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-25 15:00:00'},
#   {'dt': 1595700000,
#    'main': {'temp': 290.24,
#     'feels_like': 289.18,
#     'temp_min': 290.24,
#     'temp_max': 290.24,
#     'pressure': 1004,
#     'sea_level': 1004,
#     'grnd_level': 1002,
#     'humidity': 81,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.22, 'deg': 294},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 1.84},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-25 18:00:00'},
#   {'dt': 1595710800,
#    'main': {'temp': 287.14,
#     'feels_like': 285.82,
#     'temp_min': 287.14,
#     'temp_max': 287.14,
#     'pressure': 1004,
#     'sea_level': 1004,
#     'grnd_level': 1003,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.79, 'deg': 272},
#    'visibility': 10000,
#    'pop': 1,
#    'rain': {'3h': 1.24},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-07-25 21:00:00'},
#   {'dt': 1595721600,
#    'main': {'temp': 284.99,
#     'feels_like': 282.75,
#     'temp_min': 284.99,
#     'temp_max': 284.99,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 1003,
#     'humidity': 91,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10n'}],
#    'clouds': {'all': 85},
#    'wind': {'speed': 3.43, 'deg': 264},
#    'visibility': 10000,
#    'pop': 0.96,
#    'rain': {'3h': 0.11},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-07-26 00:00:00'},
#   {'dt': 1595732400,
#    'main': {'temp': 284.46,
#     'feels_like': 281.85,
#     'temp_min': 284.46,
#     'temp_max': 284.46,
#     'pressure': 1005,
#     'sea_level': 1005,
#     'grnd_level': 1003,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02n'}],
#    'clouds': {'all': 14},
#    'wind': {'speed': 3.82, 'deg': 254},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-07-26 03:00:00'},
#   {'dt': 1595743200,
#    'main': {'temp': 284.98,
#     'feels_like': 282.54,
#     'temp_min': 284.98,
#     'temp_max': 284.98,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 1004,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 801,
#      'main': 'Clouds',
#      'description': 'few clouds',
#      'icon': '02d'}],
#    'clouds': {'all': 17},
#    'wind': {'speed': 3.65, 'deg': 241},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-26 06:00:00'},
#   {'dt': 1595754000,
#    'main': {'temp': 288.53,
#     'feels_like': 285.8,
#     'temp_min': 288.53,
#     'temp_max': 288.53,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1005,
#     'humidity': 77,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 74},
#    'wind': {'speed': 4.51, 'deg': 232},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-26 09:00:00'},
#   {'dt': 1595764800,
#    'main': {'temp': 291,
#     'feels_like': 288,
#     'temp_min': 291,
#     'temp_max': 291,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1005,
#     'humidity': 68,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 87},
#    'wind': {'speed': 5.11, 'deg': 236},
#    'visibility': 10000,
#    'pop': 0.46,
#    'rain': {'3h': 0.38},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-26 12:00:00'},
#   {'dt': 1595775600,
#    'main': {'temp': 290.71,
#     'feels_like': 286.78,
#     'temp_min': 290.71,
#     'temp_max': 290.71,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1005,
#     'humidity': 70,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.51, 'deg': 255},
#    'visibility': 10000,
#    'pop': 0.97,
#    'rain': {'3h': 0.73},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-26 15:00:00'},
#   {'dt': 1595786400,
#    'main': {'temp': 289.46,
#     'feels_like': 285.51,
#     'temp_min': 289.46,
#     'temp_max': 289.46,
#     'pressure': 1009,
#     'sea_level': 1009,
#     'grnd_level': 1007,
#     'humidity': 75,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 6.47, 'deg': 282},
#    'visibility': 10000,
#    'pop': 0.97,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-26 18:00:00'},
#   {'dt': 1595797200,
#    'main': {'temp': 285.53,
#     'feels_like': 283.79,
#     'temp_min': 285.53,
#     'temp_max': 285.53,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1008,
#     'humidity': 88,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 98},
#    'wind': {'speed': 2.72, 'deg': 262},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-07-26 21:00:00'},
#   {'dt': 1595808000,
#    'main': {'temp': 283.69,
#     'feels_like': 281.55,
#     'temp_min': 283.69,
#     'temp_max': 283.69,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1010,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 85},
#    'wind': {'speed': 2.73, 'deg': 251},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-07-27 00:00:00'},
#   {'dt': 1595818800,
#    'main': {'temp': 283.67,
#     'feels_like': 281.84,
#     'temp_min': 283.67,
#     'temp_max': 283.67,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1009,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 93},
#    'wind': {'speed': 2.29, 'deg': 236},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-07-27 03:00:00'},
#   {'dt': 1595829600,
#    'main': {'temp': 285.58,
#     'feels_like': 284.49,
#     'temp_min': 285.58,
#     'temp_max': 285.58,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1009,
#     'humidity': 85,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 92},
#    'wind': {'speed': 1.61, 'deg': 197},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-27 06:00:00'},
#   {'dt': 1595840400,
#    'main': {'temp': 288.24,
#     'feels_like': 287.07,
#     'temp_min': 288.24,
#     'temp_max': 288.24,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1009,
#     'humidity': 74,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 1.93, 'deg': 189},
#    'visibility': 10000,
#    'pop': 0.19,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-27 09:00:00'},
#   {'dt': 1595851200,
#    'main': {'temp': 286.57,
#     'feels_like': 284.69,
#     'temp_min': 286.57,
#     'temp_max': 286.57,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1008,
#     'humidity': 89,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 3.42, 'deg': 152},
#    'visibility': 10000,
#    'pop': 0.99,
#    'rain': {'3h': 1.5},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-27 12:00:00'},
#   {'dt': 1595862000,
#    'main': {'temp': 288.41,
#     'feels_like': 288.14,
#     'temp_min': 288.41,
#     'temp_max': 288.41,
#     'pressure': 1007,
#     'sea_level': 1007,
#     'grnd_level': 1005,
#     'humidity': 94,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.34, 'deg': 163},
#    'visibility': 3752,
#    'pop': 1,
#    'rain': {'3h': 5.92},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-27 15:00:00'},
#   {'dt': 1595872800,
#    'main': {'temp': 289.57,
#     'feels_like': 289.77,
#     'temp_min': 289.57,
#     'temp_max': 289.57,
#     'pressure': 1006,
#     'sea_level': 1006,
#     'grnd_level': 1004,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 500,
#      'main': 'Rain',
#      'description': 'light rain',
#      'icon': '10d'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 2.08, 'deg': 314},
#    'visibility': 5555,
#    'pop': 1,
#    'rain': {'3h': 1.94},
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-27 18:00:00'},
#   {'dt': 1595883600,
#    'main': {'temp': 286.75,
#     'feels_like': 284.61,
#     'temp_min': 286.75,
#     'temp_max': 286.75,
#     'pressure': 1008,
#     'sea_level': 1008,
#     'grnd_level': 1006,
#     'humidity': 93,
#     'temp_kf': 0},
#    'weather': [{'id': 501,
#      'main': 'Rain',
#      'description': 'moderate rain',
#      'icon': '10n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.16, 'deg': 306},
#    'visibility': 9994,
#    'pop': 0.92,
#    'rain': {'3h': 3.48},
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-07-27 21:00:00'},
#   {'dt': 1595894400,
#    'main': {'temp': 285.03,
#     'feels_like': 282.19,
#     'temp_min': 285.03,
#     'temp_max': 285.03,
#     'pressure': 1010,
#     'sea_level': 1010,
#     'grnd_level': 1008,
#     'humidity': 90,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 100},
#    'wind': {'speed': 4.23, 'deg': 294},
#    'visibility': 10000,
#    'pop': 0.83,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-07-28 00:00:00'},
#   {'dt': 1595905200,
#    'main': {'temp': 282.2,
#     'feels_like': 279.14,
#     'temp_min': 282.2,
#     'temp_max': 282.2,
#     'pressure': 1011,
#     'sea_level': 1011,
#     'grnd_level': 1009,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 804,
#      'main': 'Clouds',
#      'description': 'overcast clouds',
#      'icon': '04n'}],
#    'clouds': {'all': 87},
#    'wind': {'speed': 3.65, 'deg': 270},
#    'visibility': 9549,
#    'pop': 0,
#    'sys': {'pod': 'n'},
#    'dt_txt': '2020-07-28 03:00:00'},
#   {'dt': 1595916000,
#    'main': {'temp': 282.49,
#     'feels_like': 279.03,
#     'temp_min': 282.49,
#     'temp_max': 282.49,
#     'pressure': 1012,
#     'sea_level': 1012,
#     'grnd_level': 1010,
#     'humidity': 92,
#     'temp_kf': 0},
#    'weather': [{'id': 803,
#      'main': 'Clouds',
#      'description': 'broken clouds',
#      'icon': '04d'}],
#    'clouds': {'all': 63},
#    'wind': {'speed': 4.31, 'deg': 268},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-28 06:00:00'},
#   {'dt': 1595926800,
#    'main': {'temp': 287.23,
#     'feels_like': 283.79,
#     'temp_min': 287.23,
#     'temp_max': 287.23,
#     'pressure': 1014,
#     'sea_level': 1014,
#     'grnd_level': 1012,
#     'humidity': 79,
#     'temp_kf': 0},
#    'weather': [{'id': 802,
#      'main': 'Clouds',
#      'description': 'scattered clouds',
#      'icon': '03d'}],
#    'clouds': {'all': 40},
#    'wind': {'speed': 5.17, 'deg': 289},
#    'visibility': 10000,
#    'pop': 0,
#    'sys': {'pod': 'd'},
#    'dt_txt': '2020-07-28 09:00:00'}],
#  'city': {'id': 2964574,
#   'name': 'Dublin',
#   'coord': {'lat': 53.344, 'lon': -6.2672},
#   'country': 'IE',
#   'population': 15000,
#   'timezone': 3600,
#   'sunrise': 1595478456,
#   'sunset': 1595536511}}

# %%
print(forecast['list'][0]['dt'])
print(forecast['list'][0]['main']['feels_like']-273.15)
print(forecast['list'][0]['weather'][0]['main'])
# Out:
# 1595505600
# 15.75
# Clouds

# %%
find_forecast(today)
# Out:
# {'feels_like': 16.230000000000018, 'weather_main': 'Clouds'}

# %%
today
# Out:
# datetime.datetime(2020, 7, 23, 11, 16, 33, 536202)

# %%
other_day = datetime.datetime(2020,7,28,11,16,33,536202)

# %%
get_prediction('1',1,datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"),48,44)
# Out:
# C:\Users\Mesel\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\Mesel\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# 322

# %%
datestring = "2020-7-4 10:10:10"
datetime_departure = datetime.datetime.strptime(datestring,'%Y-%m-%d %H:%M:%S')

# %%
datetime_departure
# Out:
# datetime.datetime(2020, 7, 4, 10, 10, 10)

# %%
get_prediction('46')

# %%
datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
# Out:
# '2020-07-27 15:01:50'

# %%
get_prediction('46A',2,datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"),792,768)
# Out:
# C:\Users\Mesel\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\Mesel\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# 1066

# %%
stopfractionsname = "stopfractions.pkl"
stopfractions = pickle.load(open(stopfractionsname,'rb'))

# %%
for stop in stopfractions[stopfractions['LINEID']=='46A'][stopfractions['DIRECTION'] == 1]['STOPPOINTID'].unique():
    print(stop)
print()
for stop in stopfractions[stopfractions['LINEID']=='46A'][stopfractions['DIRECTION'] == 2]['STOPPOINTID'].unique():
    print(stop)
# Out:
# 81
# 264
# 334
# 406
# 435
# 747
# 756
# 757
# 758
# 759
# 760
# 761
# 762
# 763
# 767
# 807
# 808
# 809
# 810
# 811
# 812
# 813
# 814
# 817
# 818
# 819
# 842
# 845
# 846
# 847
# 848
# 2007
# 2008
# 2009
# 2010
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022
# 2031
# 2032
# 2033
# 2034
# 2035
# 2036
# 2039
# 2795
# 4565
# 4566
# 4567
# 4571
# 4636
# 4962
# 6059
# 7353
#
# 2
# 192
# 278
# 320
# 461
# 768
# 769
# 770
# 771
# 772
# 773
# 774
# 775
# 776
# 777
# 786
# 792
# 795
# 796
# 797
# 798
# 799
# 800
# 801
# 802
# 803
# 804
# 805
# 806
# 807
# 906
# 907
# 908
# 909
# 2039
# 2040
# 2041
# 2042
# 2043
# 2044
# 2045
# 2046
# 2056
# 2057
# 2058
# 2059
# 2060
# 2061
# 2062
# 2063
# 2064
# 2065
# 2068
# 2069
# 2070
# 2084
# 4568
# 4569
# 4570
# 4727
# 4728
# 4962
# 7491
# 7513
# 7658
# 7689
# C:\Users\Mesel\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# C:\Users\Mesel\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.

# %%
get_prediction('39A',2,datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"),793,767)
# Out:
# C:\Users\Mesel\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-35-bdf142f2b659> in <module>
# ----> 1 get_prediction('39A',2,datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S"),793,767)
#
# <ipython-input-3-c320faf550fa> in get_prediction(route, direction, datestring, stopA, stopB)
#       4     forecast = find_forecast(datetime_departure)
#       5
# ----> 6     prediction = predict_travel_time(route,direction,datetime_departure,forecast['feels_like'],forecast['weather_main'],stopA,stopB)
#       7
#       8     return int(prediction)
#
# <ipython-input-3-c320faf550fa> in predict_travel_time(route, direction, datetime_departure, feels_like, weather_main, stopA, stopB)
#      29     total_triptime = predict_total_triptime(route,direction,datetime_departure,feels_like,weather_main)
#      30
# ---> 31     stopA_frac = stopfractions[stopfractions['LINEID']==route][stopfractions['DIRECTION']==direction][stopfractions['STOPPOINTID']==stopA]['TRIP_FRAC'].iloc[0]
#      32     stopB_frac = stopfractions[stopfractions['LINEID']==route][stopfractions['DIRECTION']==direction][stopfractions['STOPPOINTID']==stopB]['TRIP_FRAC'].iloc[0]
#      33     fraction = stopB_frac - stopA_frac
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2136
#    2137             # validate the location
# -> 2138             self._validate_integer(key, axis)
#    2139
#    2140             return self._get_loc(key, axis=axis)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    2061         len_axis = len(self.obj._get_axis(axis))
#    2062         if key >= len_axis or key < -len_axis:
# -> 2063             raise IndexError("single positional indexer is out-of-bounds")
#    2064
#    2065     def _getitem_tuple(self, tup: Tuple):
#
# IndexError: single positional indexer is out-of-bounds

# %%
get_prediction('145', 2, "2020-07-27 15:33:46", 792, 768)
# Out:
# C:\Users\Mesel\Anaconda3\lib\site-packages\ipykernel_launcher.py:31: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\Mesel\Anaconda3\lib\site-packages\ipykernel_launcher.py:32: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# 1002
